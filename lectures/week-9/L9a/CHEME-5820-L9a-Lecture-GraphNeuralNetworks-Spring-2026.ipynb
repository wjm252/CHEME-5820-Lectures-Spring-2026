# %% [markdown]
# # L9a: Introduction to Graph Neural Networks (GNNs)
# In this lecture, we will explore Graph Neural Networks (GNNs), a powerful class of neural networks designed to operate on graph-structured data. GNNs have gained significant attention in recent years due to their ability to capture complex relationships and dependencies in data represented as graphs.
#
# > __Learning Objectives:__
# >
# > By the end of this lecture, you will be able to:
# > Three learning objectives go here
#
# Let's get started!
# ___

# %% [markdown]
# ## Summary
# One direct, concise summary sentence goes here.
#
# > __Key Takeaways:__
# >
# > Three key takeaways go here
#
# One direct, concise concluding sentence goes here.
# ___
